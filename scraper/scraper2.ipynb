# %%
import LanusStats as ls
fbref = ls.Fbref()

# %%
ls.get_available_season_for_leagues('Fbref', 'Primera Division Ecuador')
# Out:
# {'id': 58, 'slug': 'Serie-A', 'seasons': {'2021', '2022', '2023', '2024'}}

# %%
fbref.get_teams_season_stats('stats', 'Primera Division Ecuador', '2021', change_columns_names=True, stats_vs=True, save_csv=True)
# Out:
# Starting to scrape teams data from Fbref...
#                    Squad  # Pl   Age  Poss  PlayingTime_MP  \
# 0           vs Barcelona    26  27.3   NaN              30
# 1   vs Club 9 de Octubre    29  27.5   NaN              30
# 2           vs CS Emelec    27  27.4   NaN              30
# 3              vs Delfín    30  27.4   NaN              30
# 4    vs Deportivo Cuenca    32  27.4   NaN              30
# 5      vs Guayaquil City    30  27.5   NaN              30
# 6       vs Independiente    38  27.6   NaN              30
# 7        vs LDU de Quito    33  27.2   NaN              30
# 8              vs Macará    32  27.5   NaN              30
# 9   vs Manta Fútbol Club    28  27.3   NaN              30
# 10        vs Mushuc Runa    30  27.4   NaN              30
# 11             vs Olmedo    32  27.3   NaN              30
# 12             vs Orense    32  27.4   NaN              30
# 13           vs SD Aucas    44  27.5   NaN              30
# ...

# %%
fbref.get_all_teams_season_stats('Primera Division Ecuador', '2024', change_columns_names=True)
# Out:
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
#                      Squad  # Pl   Age  Poss  PlayingTime_MP  \
# 0                Barcelona    28  29.8   NaN              15
# 1                CS Emelec    24  30.7   NaN              15
# 2               Cumbayá FC    28  27.2   NaN              15
# 3                   Delfín    28  26.9   NaN              15
# 4         Deportivo Cuenca    24  29.2   NaN              15
# 5              El Nacional    40  27.5   NaN              15
# ...

# %%
fbref.get_player_season_stats('stats', 'Primera Division Ecuador', '2021', save_csv=True)
# Out:
# Starting to scrape player data from Fbref...
#                Player  Nation    Pos             Squad  \
# 0    Gabriel Achilier  ec ECU     DF            Orense
# 1       Marcos Acosta  py PAR     DF            Orense
# 2         Ricardo Adé  ht HAI     DF       Mushuc Runa
# 3        Alan Aguirre  ar ARG     DF    Guayaquil City
# 4      Manuel Aguirre  ec ECU     DF  Deportivo Cuenca
# ..                ...     ...    ...               ...
# 502     Rody Zambrano  ec ECU  DF,MF       Mushuc Runa
# 503   Santiago Zamora  ec ECU     MF     Univ Católica
# 504     Alexis Zapata  co COL     MF         CS Emelec
# 505     Ismael Zúñiga  ec ECU     MF            Olmedo
# 506     Matías Zunino  uy URU  MF,DF      LDU de Quito
#
#                          Comp Age  Born  MP Starts    Min  ... G-PK PK PKatt  \
# 0    Primera Division Ecuador  35  1985  25     25  2,174  ...    4  0     0
# 1    Primera Division Ecuador  29  1991  16     16  1,440  ...    0  0     0
# ...
